# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
import datetime
from datetime import date, timedelta

# %%
data = pd.read_csv("data_cleaned.csv").drop(columns="Unnamed: 0")

# %%
pd.read_csv("preproc_data_n.csv").drop(columns="Unnamed: 0")
# Out:
#      nb_crimes nb_crimes.1      nb_crimes.2 nb_crimes.3   nb_crimes.4  \
# 0     Anchieta       Bangu  Barra da Tijuca    Botafogo  Campo Grande
# 1          NaN         NaN              NaN         NaN           NaN
# 2            4           4                3           0             6
# 3           10          21               15          12            38
# 4            5           7                3           2            26
# ...        ...         ...              ...         ...           ...
# 4016         7          16               11           9            13
# 4017         9           7                9          11             7
# 4018         5          14               12          10             8
# 4019         6           7                3           5             5
# 4020         0           0                0           1             0
#
#      nb_crimes.5     nb_crimes.6         nb_crimes.7 nb_crimes.8 nb_crimes.9  \
# 0         Centro  Cidade de Deus  Complexo do Alemao  Copacabana   Guaratiba
# 1            NaN             NaN                 NaN         NaN         NaN
# 2              2               0                   0           5           5
# 3              3               2                   0          10          11
# 4              6               0                   0           8           2
# ...          ...             ...                 ...         ...         ...
# 4016          16               0                   0          19           3
# 4017           7               2                   1          29           1
# 4018          10               1                   0          10           3
# 4019           5               0                   0          25           2
# 4020           0               0                   0           0           0
#
#       ... nb_crimes.23 nb_crimes.24  nb_crimes.25 nb_crimes.26 nb_crimes.27  \
# 0     ...        Ramos     Realengo  Rio Comprido      Rocinha   Santa Cruz
# 1     ...          NaN          NaN           NaN          NaN          NaN
# 2     ...            1            4             1            0            1
# 3     ...            9            9             7            1           22
# 4     ...            5            5             1            0           10
# ...   ...          ...          ...           ...          ...          ...
# 4016  ...            5            9             2            0            2
# 4017  ...            4            9             4            0            5
# 4018  ...            3            4             0            1            5
# 4019  ...            4            2             3            0            1
# 4020  ...            0            0             0            0            0
#
#       nb_crimes.28   nb_crimes.29 nb_crimes.30   nb_crimes.31 nb_crimes.32
# 0     Santa Teresa  Sao Cristovao       Tijuca  Vigario Geral  Vila Isabel
# 1              NaN            NaN          NaN            NaN          NaN
# 2                1              3            1              0            0
# 3                0              4            2              2            7
# 4                2              1            4              2            5
# ...            ...            ...          ...            ...          ...
# 4016             2              3            3              2            8
# 4017             2              3            3              4            4
# 4018             1              3            6              2            5
# 4019             0              1            3              2            1
# 4020             0              0            0              0            0
#
# [4021 rows x 33 columns]

# %%
data.dtypes
# Out:
# Crime_ID          object
# Crime_sub_type    object
# Crime_type        object
# Police_station    object
# Place_type        object
# Test_Date_Time    object
# Date_Time         object
# Neighborhood      object
# AR                object
# dtype: object

# %%
import preproc
preproc.get_format(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9s/md4xnzf949vc59xqd_slzxy00000gn/T/ipykernel_47725/1649942447.py in <module>
#       1 import preproc
# ----> 2 preproc.get_format(data)
#
# ~/code/black-dalia/event-forecast-rio/preproc.py in get_format(data)
#      13     2. nb_crime per 1000 inhab / day and AR'''
#      14
# ---> 15     data["Date"] = data["Date_Time"].dt.date
#      16     preprocessed_data = data.groupby(["AR", "Date"]).count()[["Crime_ID"]]
#      17     preprocessed_data.rename(columns={"Crime_ID":"nb_crimes"}, inplace=True)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     504             return PeriodProperties(data, orig)
#     505
# --> 506         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU
from keras.models import Sequential 

model = Sequential()
model.add(LSTM(units=10, activation='tanh'))
# Out:
# 2022-03-02 12:43:43.232280: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
