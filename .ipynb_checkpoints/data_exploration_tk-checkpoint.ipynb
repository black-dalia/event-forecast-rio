# %%
# Import section
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
importe datetime

# %%
# Data loading
data1 = pd.read_csv('/Users/thomaskremer/code/black-dalia/event-forecast-rio/raw_data/parte1.csv', sep=';', encoding = 'iso-8859-1')

# %%
# Filtering on Rio de Janeiro
data1 = data1[data1['municipio_fato'] == 'Rio de Janeiro (Capital)']
data1.head()
# Out:
#         controle   ano      mes              titulo_do     total_rbft  \
# 0  00787401-2009  2009  Janeiro  Lesão corporal dolosa  Não se aplica
# 5  01137431-2009  2009  Janeiro  Lesão corporal dolosa  Não se aplica
# 6  01137431-2009  2009  Janeiro  Lesão corporal dolosa  Não se aplica
# 7  01137431-2009  2009  Janeiro  Lesão corporal dolosa  Não se aplica
# 9  02023941-2009  2009  Janeiro  Lesão corporal dolosa  Não se aplica
#
#   conteudo                                                dp  \
# 0  vítimas                          043a. Pedra de Guaratiba
# 5  vítimas  Delegacia de Atendimento à Mulher - Campo Grande
# 6  vítimas  Delegacia de Atendimento à Mulher - Campo Grande
# 7  vítimas  Delegacia de Atendimento à Mulher - Campo Grande
# 9  vítimas                              040a. Honório Gurgel
#
#                        cisp    data_com   data_fato  ...     risp       local  \
# 0  043a. Pedra de Guaratiba  2009-01-01  2009-01-01  ...  RISP 02       Praia
# ...

# %%
# Removing columns
kept_columns = ['controle', 'titulo_do', 'total_rbft', 'cisp', 'data_fato', 'hora_fato', 'local', 'bairro_fato']
data1 = data1[kept_columns]
data1.head()
# Out:
#         controle              titulo_do     total_rbft  \
# 0  00787401-2009  Lesão corporal dolosa  Não se aplica
# 5  01137431-2009  Lesão corporal dolosa  Não se aplica
# 6  01137431-2009  Lesão corporal dolosa  Não se aplica
# 7  01137431-2009  Lesão corporal dolosa  Não se aplica
# 9  02023941-2009  Lesão corporal dolosa  Não se aplica
#
#                        cisp   data_fato hora_fato       local  \
# 0  043a. Pedra de Guaratiba  2009-01-01     04:30       Praia
# 5        035a. Campo Grande  2009-01-01     19:00  Residência
# 6        035a. Campo Grande  2009-01-01     19:00  Residência
# 7        035a. Campo Grande  2009-01-01     19:00  Residência
# 9      040a. Honório Gurgel  2008-12-31     20:30  Residência
#
#                       bairro_fato
# 0  PRAIA DA BRISA/PEDRA DE GUARAT
# 5                      SANTISSIMO
# 6                      SANTISSIMO
# 7                      SANTISSIMO
# 9                  HONÓRIO GURGEL

# %%
# Renaming columns
data1.columns = ['Crime_ID', 'Crime_sub_type', 'Crime_type', 'Police_station', 'Date', 'Time', 'Place_type', 'Neighborhood']
data1.head()
# Out:
#         Crime_ID         Crime_sub_type     Crime_type  \
# 0  00787401-2009  Lesão corporal dolosa  Não se aplica
# 5  01137431-2009  Lesão corporal dolosa  Não se aplica
# 6  01137431-2009  Lesão corporal dolosa  Não se aplica
# 7  01137431-2009  Lesão corporal dolosa  Não se aplica
# 9  02023941-2009  Lesão corporal dolosa  Não se aplica
#
#              Police_station        Date   Time  Place_type  \
# 0  043a. Pedra de Guaratiba  2009-01-01  04:30       Praia
# 5        035a. Campo Grande  2009-01-01  19:00  Residência
# 6        035a. Campo Grande  2009-01-01  19:00  Residência
# 7        035a. Campo Grande  2009-01-01  19:00  Residência
# 9      040a. Honório Gurgel  2008-12-31  20:30  Residência
#
#                      Neighborhood
# 0  PRAIA DA BRISA/PEDRA DE GUARAT
# 5                      SANTISSIMO
# 6                      SANTISSIMO
# 7                      SANTISSIMO
# 9                  HONÓRIO GURGEL

# %%
# Removing duplicates
data1 = data1.drop_duplicates(subset="Crime_ID")
data1.head()
# Out:
#          Crime_ID         Crime_sub_type     Crime_type  \
# 0   00787401-2009  Lesão corporal dolosa  Não se aplica
# 5   01137431-2009  Lesão corporal dolosa  Não se aplica
# 9   02023941-2009  Lesão corporal dolosa  Não se aplica
# 15  02646521-2009  Lesão corporal dolosa  Não se aplica
# 19  04751871-2009  Lesão corporal dolosa  Não se aplica
#
#               Police_station        Date   Time   Place_type  \
# 0   043a. Pedra de Guaratiba  2009-01-01  04:30        Praia
# 5         035a. Campo Grande  2009-01-01  19:00   Residência
# 9       040a. Honório Gurgel  2008-12-31  20:30   Residência
# 15        035a. Campo Grande  2009-01-01  19:00   Residência
# 19        035a. Campo Grande  2009-01-01  01:30  Via pública
#
#                       Neighborhood
# 0   PRAIA DA BRISA/PEDRA DE GUARAT
# 5                       SANTISSIMO
# 9                   HONÓRIO GURGEL
# 15                     VASCONCELOS
# 19                    CAMPO GRANDE

# %%
data1['Time'] = pd.to_datetime(data1['Time'], format='%h-%m', errors = 'coerce') # Passing date to datetime format
data1['Date'] = pd.to_datetime(data1['Date'], format='%y-%m-%d', errors = 'coerce') # Passing date to d
data1.dtypes
# Out:
# Crime_ID                  object
# Crime_sub_type            object
# Crime_type                object
# Police_station            object
# Date              datetime64[ns]
# Time              datetime64[ns]
# Place_type                object
# Neighborhood              object
# dtype: object

# %%
#All in one

# Data loading
data1 = pd.read_csv('/Users/thomaskremer/code/black-dalia/event-forecast-rio/raw_data/parte1.csv', sep=';', encoding = 'iso-8859-1')
data2 = pd.read_csv('/Users/thomaskremer/code/black-dalia/event-forecast-rio/raw_data/parte2.csv', sep=';', encoding = 'iso-8859-1')
data3 = pd.read_csv('/Users/thomaskremer/code/black-dalia/event-forecast-rio/raw_data/parte3.csv', sep=';', encoding = 'iso-8859-1')
data4 = pd.read_csv('/Users/thomaskremer/code/black-dalia/event-forecast-rio/raw_data/parte4.csv', sep=';', encoding = 'iso-8859-1')
kept_columns = ['controle', 'ano', 'titulo_do', 'total_rbft', 'cisp', 'data_fato', 'hora_fato', 'local', 'bairro_fato']
eng_columns = ['Crime_ID', 'Year', 'Crime_sub_type', 'Crime_type', 'Police_station', 'Date', 'Time', 'Place_type', 'Neighborhood']

# %%
data = pd.concat([data1, data2, data3, data4]) # Merging all datasets
data = data[data['municipio_fato'] == 'Rio de Janeiro (Capital)'] # Filtering on Rio de Janeiro only
                 
data = data[kept_columns] # Removing useless columns
                 
data.columns = eng_columns  # Renaming columns in English

data['Time'] = data['Time'].astype(str)
data = data[len(data['Time']) == 5]

data["Date_time"] = (data["Date"].map(str) + " " + data["Time"])       
data["Date_time"] = pd.to_datetime(data["Date_time"], format="%Y/%m/%d %H:%M")
data = data.drop_duplicates(subset="Crime_ID") # Removing duplicates

data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.12/envs/event-forecast-rio/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.pyenv/versions/3.8.12/envs/event-forecast-rio/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.8.12/envs/event-forecast-rio/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# ...

# %%
data.dtypes
# Out:
# Crime_ID                  object
# Year                       int64
# Crime_sub_type            object
# Crime_type                object
# Police_station            object
# Date              datetime64[ns]
# Time                      object
# Place_type                object
# Neighborhood              object
# dtype: object

# %%
data[data['Date'] > '2019-12-29']
# Out:
#              Crime_ID  Year      Crime_sub_type     Crime_type  \
# 687707  25441631-2019  2019    Homicídio doloso  Não se aplica
# 699594  98489931-2019  2019  Roubo a transeunte          Roubo
# 700132  00821391-2019  2019             Estupro  Não se aplica
# 700548  00106391-2019  2019  Roubo a transeunte          Roubo
# 700549  00239931-2019  2019   Furto de veículos          Furto
# ...               ...   ...                 ...            ...
# 701658  97578571-2019  2019  Furto a transeunte          Furto
# 701662  98452031-2019  2019  Furto a transeunte          Furto
# 701663  98535391-2019  2019  Furto a transeunte          Furto
# 701667  99563211-2019  2019    Roubo de veículo          Roubo
# 701668  99585861-2019  2019  Furto a transeunte          Furto
#
#                    Police_station       Date      Time            Place_type  \
# 687707               039a. Pavuna 2019-12-31  08:00:00              Ignorado
# ...

# %%
data['Time'] = pd.to_datetime(data['Time'],format='%H:%M', errors='coerce').dt.time # Passing time to datetime format
data['Date'] = pd.to_datetime(data['Date']) # Passing date to datetime format
data = data[data['Date'] > '2008-01-31'] # Removing irrelevant date samples
