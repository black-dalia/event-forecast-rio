# %% [markdown]
# Model 3 RNN

# %%
# %load_ext autoreload

# %autoreload 2

# %%
import preproc_RNN_LSTM
import pandas as pd
import plot_evaluate_models
import matplotlib.pyplot as plt
from metrics import get_baseline_data
import numpy as np
import math
import tensorflow
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.layers import TimeDistributed, Dropout, BatchNormalization
from tensorflow.keras import optimizers, metrics
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import RobustScaler
from baseline import get_baseline_actual, get_baseline_predictions, forecast_accuracy

# %% [markdown]
# # Import imput data

# %%
data = preproc_RNN_LSTM.get_baseline_data("raw_data/preproc_data_rate.csv")

# %% [markdown]
# # Set parameters

# %%
n_sequences=4000
length=150
prediction_horizon = 31

# %% [markdown]
# # Modelling

# %% [markdown]
# ## set training and test set

# %%
X_train, y_train, X_test, y_test = preproc_RNN_LSTM.get_train_test(data,n_sequences,length, prediction_horizon)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((4000, 119, 30), (4000, 31, 30), (1000, 119, 30), (1000, 31, 30))

# %% [markdown]
# ## define model

# %%
#model1 = preproc_RNN_LSTM.model(n_sequences, length-prediction_horizon, 30, prediction_horizon)

model1 = models.Sequential()
model1.add(layers.LSTM(128, return_sequences=False, activation="tanh", \
    input_shape = (length-prediction_horizon, 30)))
model1.add(layers.RepeatVector(prediction_horizon))
#model.add(Dropout(0.4))
model1.add(layers.LSTM(40, return_sequences=True, activation="tanh"))
# added 
#model.add(BatchNormalization())
#model.add(Dropout(0.4))
model1.add(layers.TimeDistributed(layers.Dense(30,"relu")))
model1.compile(loss="mse",
            optimizer="rmsprop")

# %% [markdown]
# ## train model

# %%
#preproc_RNN_LSTM.fit_model(X_train, y_train, model1)
es = EarlyStopping(monitor='val_loss', verbose=1, patience=20, restore_best_weights=True)
hist = model1.fit(X_train, y_train, 
                 callbacks=[es],
                 epochs = 2000,
                 validation_split =0.3, 
                 batch_size=16
                )
# Out:
# Epoch 1/2000
# 175/175 [==============================] - 9s 42ms/step - loss: 0.0461 - val_loss: 0.0483
# Epoch 2/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0435 - val_loss: 0.0471
# Epoch 3/2000
# 175/175 [==============================] - 8s 46ms/step - loss: 0.0434 - val_loss: 0.0487
# Epoch 4/2000
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0420 - val_loss: 0.0450
# Epoch 5/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0403 - val_loss: 0.0434
# Epoch 6/2000
# 175/175 [==============================] - 7s 37ms/step - loss: 0.0395 - val_loss: 0.0442
# Epoch 7/2000
# 175/175 [==============================] - 8s 45ms/step - loss: 0.0384 - val_loss: 0.0420
# Epoch 8/2000
# 175/175 [==============================] - 8s 47ms/step - loss: 0.0378 - val_loss: 0.0407
# Epoch 9/2000
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0382 - val_loss: 0.0407
# Epoch 10/2000
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0362 - val_loss: 0.0402
# Epoch 11/2000
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0349 - val_loss: 0.0375
# Epoch 12/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0382 - val_loss: 0.0391
# Epoch 13/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0344 - val_loss: 0.0371
# Epoch 14/2000
# 175/175 [==============================] - 7s 37ms/step - loss: 0.0339 - val_loss: 0.0367
# Epoch 15/2000
# 175/175 [==============================] - 7s 37ms/step - loss: 0.0333 - val_loss: 0.0357
# Epoch 16/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0330 - val_loss: 0.0368
# Epoch 17/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0324 - val_loss: 0.0354
# Epoch 18/2000
# 175/175 [==============================] - 7s 42ms/step - loss: 0.0321 - val_loss: 0.0368
# Epoch 19/2000
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0319 - val_loss: 0.0354
# Epoch 20/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 21/2000
# 175/175 [==============================] - 7s 37ms/step - loss: 0.0315 - val_loss: 0.0350
# Epoch 22/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0310 - val_loss: 0.0370
# Epoch 23/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0309 - val_loss: 0.0348
# Epoch 24/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0306 - val_loss: 0.0352
# Epoch 25/2000
# 175/175 [==============================] - 8s 47ms/step - loss: 0.0308 - val_loss: 0.0338
# Epoch 26/2000
# 175/175 [==============================] - 7s 41ms/step - loss: 0.0303 - val_loss: 0.0331
# Epoch 27/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0300 - val_loss: 0.0346
# Epoch 28/2000
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0297 - val_loss: 0.0347
# Epoch 29/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0297 - val_loss: 0.0329
# Epoch 30/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0293 - val_loss: 0.0322
# Epoch 31/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0287 - val_loss: 0.0375
# Epoch 32/2000
# 175/175 [==============================] - 7s 37ms/step - loss: 0.0293 - val_loss: 0.0324
# Epoch 33/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0289 - val_loss: 0.0320
# Epoch 34/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0285 - val_loss: 0.0332
# Epoch 35/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0286 - val_loss: 0.0330
# Epoch 36/2000
# 175/175 [==============================] - 7s 37ms/step - loss: 0.0285 - val_loss: 0.0319
# Epoch 37/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0279 - val_loss: 0.0320
# Epoch 38/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0281 - val_loss: 0.0331
# Epoch 39/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0290 - val_loss: 0.0340
# Epoch 40/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0277 - val_loss: 0.0304
# Epoch 41/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0278 - val_loss: 0.0341
# Epoch 42/2000
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0278 - val_loss: 0.0304
# Epoch 43/2000
# 175/175 [==============================] - 9s 51ms/step - loss: 0.0271 - val_loss: 0.0310
# Epoch 44/2000
# 175/175 [==============================] - 9s 54ms/step - loss: 0.0273 - val_loss: 0.0323
# Epoch 45/2000
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0268 - val_loss: 0.0328
# Epoch 46/2000
# 175/175 [==============================] - 7s 41ms/step - loss: 0.0267 - val_loss: 0.0310
# Epoch 47/2000
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0268 - val_loss: 0.0328
# Epoch 48/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0263 - val_loss: 0.0349
# Epoch 49/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0268 - val_loss: 0.0304
# Epoch 50/2000
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0259 - val_loss: 0.0298
# Epoch 51/2000
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0261 - val_loss: 0.0288
# Epoch 52/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0254 - val_loss: 0.0299
# Epoch 53/2000
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0260 - val_loss: 0.0283
# Epoch 54/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0255 - val_loss: 0.0303
# Epoch 55/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0255 - val_loss: 0.0277
# Epoch 56/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0252 - val_loss: 0.0283
# Epoch 57/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0250 - val_loss: 0.0293
# Epoch 58/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0249 - val_loss: 0.0315
# Epoch 59/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0247 - val_loss: 0.0266
# Epoch 60/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0249 - val_loss: 0.0274
# Epoch 61/2000
# 175/175 [==============================] - 8s 46ms/step - loss: 0.0241 - val_loss: 0.0278
# Epoch 62/2000
# 175/175 [==============================] - 7s 41ms/step - loss: 0.0243 - val_loss: 0.0314
# Epoch 63/2000
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0246 - val_loss: 0.0300
# Epoch 64/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0243 - val_loss: 0.0314
# Epoch 65/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0243 - val_loss: 0.0276
# Epoch 66/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0241 - val_loss: 0.0254
# Epoch 67/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0235 - val_loss: 0.0255
# Epoch 68/2000
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0233 - val_loss: 0.0266
# Epoch 69/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0232 - val_loss: 0.0266
# Epoch 70/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0228 - val_loss: 0.0270
# Epoch 71/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0233 - val_loss: 0.0254
# Epoch 72/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0229 - val_loss: 0.0255
# Epoch 73/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0222 - val_loss: 0.0264
# Epoch 74/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0226 - val_loss: 0.0264
# Epoch 75/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0224 - val_loss: 0.0255
# Epoch 76/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0224 - val_loss: 0.0290
# Epoch 77/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0228 - val_loss: 0.0253
# Epoch 78/2000
# 175/175 [==============================] - 8s 44ms/step - loss: 0.0220 - val_loss: 0.0243
# Epoch 79/2000
# 175/175 [==============================] - 8s 47ms/step - loss: 0.0219 - val_loss: 0.0250
# Epoch 80/2000
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0219 - val_loss: 0.0244
# Epoch 81/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0216 - val_loss: 0.0238
# Epoch 82/2000
# 175/175 [==============================] - 7s 37ms/step - loss: 0.0221 - val_loss: 0.0243
# Epoch 83/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0214 - val_loss: 0.0256
# Epoch 84/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0209 - val_loss: 0.0274
# Epoch 85/2000
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0213 - val_loss: 0.0268
# Epoch 86/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0210 - val_loss: 0.0216
# Epoch 87/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0209 - val_loss: 0.0243
# Epoch 88/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0212 - val_loss: 0.0274
# Epoch 89/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0213 - val_loss: 0.0226
# Epoch 90/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0203 - val_loss: 0.0243
# Epoch 91/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0209 - val_loss: 0.0249
# Epoch 92/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0204 - val_loss: 0.0232
# Epoch 93/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0200 - val_loss: 0.0300
# Epoch 94/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0205 - val_loss: 0.0270
# Epoch 95/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0201 - val_loss: 0.0244
# Epoch 96/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0197 - val_loss: 0.0247
# Epoch 97/2000
# 175/175 [==============================] - 9s 50ms/step - loss: 0.0197 - val_loss: 0.0200
# Epoch 98/2000
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0199 - val_loss: 0.0224
# Epoch 99/2000
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0198 - val_loss: 0.0224
# Epoch 100/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0196 - val_loss: 0.0238
# Epoch 101/2000
# 175/175 [==============================] - 7s 37ms/step - loss: 0.0199 - val_loss: 0.0277
# Epoch 102/2000
# 175/175 [==============================] - 7s 37ms/step - loss: 0.0196 - val_loss: 0.0257
# Epoch 103/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0194 - val_loss: 0.0237
# Epoch 104/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0191 - val_loss: 0.0250
# Epoch 105/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0209 - val_loss: 0.0249
# Epoch 106/2000
# 175/175 [==============================] - 6s 35ms/step - loss: 0.0195 - val_loss: 0.0224
# Epoch 107/2000
# 175/175 [==============================] - 6s 35ms/step - loss: 0.0190 - val_loss: 0.0208
# Epoch 108/2000
# 175/175 [==============================] - 6s 34ms/step - loss: 0.0189 - val_loss: 0.0260
# Epoch 109/2000
# 175/175 [==============================] - 6s 35ms/step - loss: 0.0193 - val_loss: 0.0271
# Epoch 110/2000
# 175/175 [==============================] - 6s 35ms/step - loss: 0.0207 - val_loss: 0.0250
# Epoch 111/2000
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0202 - val_loss: 0.0217
# Epoch 112/2000
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0185 - val_loss: 0.0285
# Epoch 113/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0187 - val_loss: 0.0218
# Epoch 114/2000
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0189 - val_loss: 0.0221
# Epoch 115/2000
# 175/175 [==============================] - 7s 42ms/step - loss: 0.0181 - val_loss: 0.0215
# Epoch 116/2000
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0177 - val_loss: 0.0211
# Epoch 117/2000
# 175/175 [==============================] - ETA: 0s - loss: 0.0185Restoring model weights from the end of the best epoch: 97.
# 175/175 [==============================] - 7s 37ms/step - loss: 0.0185 - val_loss: 0.0224
# Epoch 00117: early stopping

# %% [markdown]
# # Check outputs

# %% [markdown]
# ## Check validation set

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(['Train', 'Validation'])
plt.show()

# %% [markdown]
# ## Check predicted vs actual on test set

# %%
y_pred_df = plot_evaluate_models.compute_plot_pred_multi(data,hist.model,length, prediction_horizon)
# Out:
# /Users/desireepetrilli/Documents/event-forecast-rio/baseline.py:19: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   baseline_mean = baseline_data.mean().to_frame().T
# Prediction MSE (computed on test set):0.08847010642529601
# Baseline MSE (computed on test set):0.04010388681705765

# %% [markdown]
# # Compare to baseline

# %%
actual = get_baseline_actual(data).drop(columns="Date")

# %%
baseline = get_baseline_predictions(data)

# %%
forecast_accuracy(actual,baseline)
# Out:
# {'mse': 0.05266306588502226,
#  'mae': 0.049240814256642985,
#  'corr': 0.9999999999999999}

# %% [markdown]
# # Check function

# %%
data_wo_date = data.drop(columns="Date")
len_ = int(0.8*data_wo_date.shape[0])
data_test = data_wo_date[len_:]

# %%
int((804-(length-prediction_horizon))/prediction_horizon)+1
# Out:
# 23

# %%
i = 0
print(f"input starts at {i*prediction_horizon}")
print(f"input ends at {i*prediction_horizon+(length-prediction_horizon)} (not incl)")

data_test_temp = data_wo_date[i*prediction_horizon:i*prediction_horizon+(length-prediction_horizon)]
data_test_temp = np.array(data_test_temp)
data_test_temp = data_test_temp.reshape(1,(length-prediction_horizon),30)
y_pred_temp_0 = model1.predict(data_test_temp).tolist()[0]
print(f"output starts at {i*prediction_horizon+(length-prediction_horizon)}")
print(f"output ends at {i*prediction_horizon+(length-prediction_horizon) +31} (not incl)")
#y_pred = y_pred + y_pred_temp
y_pred_temp_0_df = pd.DataFrame(y_pred_temp_0, columns = data_wo_date.columns)
#y_pred_temp_0_df
# Out:
# input starts at 0
# input ends at 119 (not incl)
# output starts at 119
# output ends at 150 (not incl)

# %%
i = 1
print(f"input starts at {i*prediction_horizon}")
print(f"input ends at {i*prediction_horizon+(length-prediction_horizon)} (not incl)")

i*prediction_horizon+(length-prediction_horizon)
data_test_temp = data_wo_date[i*prediction_horizon:i*prediction_horizon+(length-prediction_horizon)]
data_test_temp = np.array(data_test_temp)
data_test_temp = data_test_temp.reshape(1,(length-prediction_horizon),30)

y_pred_temp_1 = model1.predict(data_test_temp).tolist()[0]
print(f"output starts at {i*prediction_horizon+(length-prediction_horizon)}")
print(f"output ends at {i*prediction_horizon+(length-prediction_horizon) +31} (not incl)")

y_pred_temp_1_df = pd.DataFrame(y_pred_temp_1, columns = data_wo_date.columns)
#y_pred_temp_1_df
# Out:
# input starts at 31
# input ends at 150 (not incl)
# output starts at 150
# output ends at 181 (not incl)

# %%
plt.plot(y_pred_temp_0_df.Anchieta)

# %%
plt.plot(y_pred_temp_1_df.Anchieta)

# %%
fig, ax = plt.subplots(1,2,figsize=(16,5), sharey=True)
ax[0].plot(y_pred_temp_0_df.Anchieta)
ax[1].plot(y_pred_temp_1_df.Anchieta)
