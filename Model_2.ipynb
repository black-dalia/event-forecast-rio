# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import math

# %%
#data cleaning
import clean
import preproc

#RNN cleaning
from RNN_preproc_uni import get_train_test

# %%
#model
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers, metrics
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
import datetime
from datetime import date, timedelta
from clean import clean_all, get_data, get_bairros_data
from preproc import get_format, get_popfile, clean_pop_data, extract_ts
idx = pd.IndexSlice

# %% [markdown]
# ## Data

# %%
data1, data2, data3, data4 = clean.get_data()
data = clean.clean_all(data1, data2, data3, data4, clean.get_bairros_data())

# %%
preproc_data_n, preproc_data_rate = preproc.get_format(data)

# %%
X_train, y_train, X_test, y_test = get_train_test(preproc_data_rate, 1000, 100, "all_AR")
# Out:
# /Users/kavithaapp/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
X_train.shape,y_train.shape, X_test.shape, y_test.shape
# Out:
# ((30000, 69, 1), (30000, 31), (7500, 69, 1), (7500, 31))

# %% [markdown]
# ## Model

# %%
def init_model():
    metric = metrics.MAPE
    opt = optimizers.RMSprop(learning_rate=0.001)
    
    model = models.Sequential()
    model.add(layers.LSTM(30, return_sequences=True, activation='tanh',input_shape = (69,1)))
    model.add(layers.LSTM(10, activation='tanh'))
    model.add(layers.Dense(5, activation='relu'))
    model.add(layers.Dense(31, activation='linear'))
    
    model.compile(loss='mse', 
                  optimizer=opt, 
                  metrics=[metric])
    
    return model

# %%
es = EarlyStopping(monitor='val_loss', verbose=1, patience=20, restore_best_weights=True)

# %%
# Fitting the model
def fit(model,x,y):
    hist = model.fit(x, y,
            validation_split=0.3,
            epochs=100, 
            batch_size=16,
            callbacks=[es], verbose=1)
    return hist

# %%
model = init_model()
history = fit(model, X_train,y_train)
# Out:
# 2022-03-06 14:17:28.514320: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-06 14:17:28.744900: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 1313/1313 [==============================] - 27s 20ms/step - loss: 0.0631 - mean_absolute_percentage_error: 4555505.5000 - val_loss: 0.0213 - val_mean_absolute_percentage_error: 4390650.5000
# Epoch 2/100
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.0516 - mean_absolute_percentage_error: 3075970.0000 - val_loss: 0.0208 - val_mean_absolute_percentage_error: 5065161.5000
# Epoch 3/100
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.0512 - mean_absolute_percentage_error: 3153289.5000 - val_loss: 0.0207 - val_mean_absolute_percentage_error: 4550763.5000
# Epoch 4/100
# 1313/1313 [==============================] - 26s 19ms/step - loss: 0.0509 - mean_absolute_percentage_error: 3126881.0000 - val_loss: 0.0205 - val_mean_absolute_percentage_error: 4607367.0000
# Epoch 5/100
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.0508 - mean_absolute_percentage_error: 3075692.5000 - val_loss: 0.0209 - val_mean_absolute_percentage_error: 5586657.5000
# Epoch 6/100
# 1313/1313 [==============================] - 27s 21ms/step - loss: 0.0508 - mean_absolute_percentage_error: 2980300.7500 - val_loss: 0.0207 - val_mean_absolute_percentage_error: 4518584.5000
# Epoch 7/100
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.0506 - mean_absolute_percentage_error: 2942099.7500 - val_loss: 0.0205 - val_mean_absolute_percentage_error: 4076205.0000
# Epoch 8/100
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.0506 - mean_absolute_percentage_error: 2888773.5000 - val_loss: 0.0206 - val_mean_absolute_percentage_error: 5566930.0000
# Epoch 9/100
# 1313/1313 [==============================] - 27s 21ms/step - loss: 0.0506 - mean_absolute_percentage_error: 2829071.2500 - val_loss: 0.0207 - val_mean_absolute_percentage_error: 5279774.5000
# Epoch 10/100
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.0504 - mean_absolute_percentage_error: 2870841.7500 - val_loss: 0.0208 - val_mean_absolute_percentage_error: 3758791.0000
# Epoch 11/100
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.0525 - mean_absolute_percentage_error: 3330446.2500 - val_loss: 0.0212 - val_mean_absolute_percentage_error: 4820237.0000
# Epoch 12/100
# 1313/1313 [==============================] - 25s 19ms/step - loss: 0.0513 - mean_absolute_percentage_error: 3203455.2500 - val_loss: 0.0210 - val_mean_absolute_percentage_error: 6311330.0000
# Epoch 13/100
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.0507 - mean_absolute_percentage_error: 3058062.5000 - val_loss: 0.0209 - val_mean_absolute_percentage_error: 5695462.0000
# Epoch 14/100
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.0504 - mean_absolute_percentage_error: 2944219.0000 - val_loss: 0.0205 - val_mean_absolute_percentage_error: 4415495.5000
# Epoch 15/100
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.0505 - mean_absolute_percentage_error: 2932265.2500 - val_loss: 0.0209 - val_mean_absolute_percentage_error: 4666160.5000
# Epoch 16/100
# 1313/1313 [==============================] - 27s 20ms/step - loss: 0.0501 - mean_absolute_percentage_error: 2989842.2500 - val_loss: 0.0208 - val_mean_absolute_percentage_error: 4456101.0000
# Epoch 17/100
# 1313/1313 [==============================] - 25s 19ms/step - loss: 0.0499 - mean_absolute_percentage_error: 2975189.2500 - val_loss: 0.0215 - val_mean_absolute_percentage_error: 6273264.5000
# Epoch 18/100
# 1313/1313 [==============================] - 25s 19ms/step - loss: 0.0501 - mean_absolute_percentage_error: 2928899.5000 - val_loss: 0.0210 - val_mean_absolute_percentage_error: 4770510.0000
# Epoch 19/100
# 1313/1313 [==============================] - 24s 19ms/step - loss: 0.0505 - mean_absolute_percentage_error: 2867896.7500 - val_loss: 0.0213 - val_mean_absolute_percentage_error: 5262545.0000
# Epoch 20/100
# 1313/1313 [==============================] - 24s 19ms/step - loss: 0.0503 - mean_absolute_percentage_error: 2934325.7500 - val_loss: 0.0209 - val_mean_absolute_percentage_error: 5441179.5000
# Epoch 21/100
# 1313/1313 [==============================] - 25s 19ms/step - loss: 0.0504 - mean_absolute_percentage_error: 2952275.2500 - val_loss: 0.0214 - val_mean_absolute_percentage_error: 4465260.5000
# Epoch 22/100
# 1313/1313 [==============================] - 25s 19ms/step - loss: 0.0500 - mean_absolute_percentage_error: 2934032.0000 - val_loss: 0.0209 - val_mean_absolute_percentage_error: 4445663.0000
# Epoch 23/100
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.0502 - mean_absolute_percentage_error: 2939220.0000 - val_loss: 0.0211 - val_mean_absolute_percentage_error: 5064695.5000
# Epoch 24/100
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.0498 - mean_absolute_percentage_error: 2878997.5000 - val_loss: 0.0213 - val_mean_absolute_percentage_error: 6081395.0000
# Epoch 25/100
# 1313/1313 [==============================] - 26s 19ms/step - loss: 0.0498 - mean_absolute_percentage_error: 2868465.0000 - val_loss: 0.0209 - val_mean_absolute_percentage_error: 4503228.0000
# Epoch 26/100
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.0499 - mean_absolute_percentage_error: 2927376.0000 - val_loss: 0.0221 - val_mean_absolute_percentage_error: 4500868.0000
# Epoch 27/100
# 1313/1313 [==============================] - 25s 19ms/step - loss: 0.0498 - mean_absolute_percentage_error: 2900451.2500 - val_loss: 0.0214 - val_mean_absolute_percentage_error: 5936301.0000
# Epoch 28/100
# 1313/1313 [==============================] - 25s 19ms/step - loss: 0.0497 - mean_absolute_percentage_error: 2814298.0000 - val_loss: 0.0228 - val_mean_absolute_percentage_error: 7041761.0000
# Epoch 29/100
# 1313/1313 [==============================] - 25s 19ms/step - loss: 0.0496 - mean_absolute_percentage_error: 2951658.5000 - val_loss: 0.0214 - val_mean_absolute_percentage_error: 5563369.0000
# Epoch 30/100
# 1313/1313 [==============================] - 26s 20ms/step - loss: 0.0498 - mean_absolute_percentage_error: 2902360.7500 - val_loss: 0.0217 - val_mean_absolute_percentage_error: 4500278.0000
# Epoch 31/100
# 1313/1313 [==============================] - 28s 21ms/step - loss: 0.0497 - mean_absolute_percentage_error: 2929500.2500 - val_loss: 0.0220 - val_mean_absolute_percentage_error: 5156798.0000
# Epoch 32/100
# 1313/1313 [==============================] - 27s 20ms/step - loss: 0.0495 - mean_absolute_percentage_error: 2941970.0000 - val_loss: 0.0220 - val_mean_absolute_percentage_error: 5024747.0000
# Epoch 33/100
# 1313/1313 [==============================] - 27s 21ms/step - loss: 0.0495 - mean_absolute_percentage_error: 2957997.2500 - val_loss: 0.0216 - val_mean_absolute_percentage_error: 5137784.0000
# Epoch 34/100
# 1313/1313 [==============================] - 27s 20ms/step - loss: 0.0493 - mean_absolute_percentage_error: 2917278.0000 - val_loss: 0.0223 - val_mean_absolute_percentage_error: 5291948.0000
# Restoring model weights from the end of the best epoch.
# Epoch 00034: early stopping

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 69, 30)            3840
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10)                1640
# _________________________________________________________________
# dense (Dense)                (None, 5)                 55
# _________________________________________________________________
# dense_1 (Dense)              (None, 31)                186
# =================================================================
# Total params: 5,721
# Trainable params: 5,721
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_pred = history.model.predict(X_test)

# %%
plt.plot(history.history["loss"],c="red")
plt.plot(history.history["val_loss"], c="blue")

# %%
y_pred[0]
# Out:
# array([0.0513028 , 0.04953071, 0.04320487, 0.05099588, 0.05309632,
#        0.05321736, 0.06000119, 0.05287004, 0.05917627, 0.0580887 ,
#        0.05222526, 0.0564879 , 0.0522838 , 0.05073046, 0.05271966,
#        0.05294979, 0.0468304 , 0.05041108, 0.05539678, 0.04785477,
#        0.04949731, 0.04358396, 0.04930948, 0.04900224, 0.04955131,
#        0.05169599, 0.05076971, 0.05052479, 0.04960932, 0.05057566,
#        0.05843619], dtype=float32)

# %%
y_test.shape, y_pred.shape
# Out:
# ((7500, 31), (7500, 31))

# %%
plt.plot(range(31),y_pred[600],color="r")
plt.plot(range(31),y_test[600],color="b")

# %%
data=preproc_data_rate.droplevel(level=0,axis=1)

# %%
#split test/train... use test only
len_ = int(0.8*df.shape[0])
df_test = df[len_:]

sample_len = 100 #sample length
pred_len = 31 #prediction length
train_len = sample_len - pred_len #length of X-variable
df = data
y_pred_order_int = []
size = int((df_test.shape[0]-(sample_len-pred_len))/pred_len)+1
no_regions = 30

for i in range(size):
    data_select = np.array(df_test[i*pred_len:i*pred_len+(sample_len-pred_len)]).T
    X_test_order = data_select.reshape(data_select.shape[0],data_select.shape[1],1)
    y_pred_order = history.model.predict(X_test_order).tolist()
    y_pred_order_int.append(y_pred_order)

y_pred_order_int=np.array(y_pred_order_int)

# %%
fig, axs = plt.subplots(no_regions,1,figsize=(20,100))
for r in range(no_regions):
    y_pred_order = np.concatenate(y_pred_order_int[:,r,:])
    actual = np.array(data_test[(length-pred_len):])[:,r]
    axs[r].plot(y_pred_order,color="r")
    axs[r].plot(actual,color="b")

plt.show()
