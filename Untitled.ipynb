# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import unidecode
import fuzzymatcher

# %%
# Data loading
def get_data():
    data1 = pd.read_csv('raw_data/parte1.csv', sep=';', encoding = 'iso-8859-1')
    data2 = pd.read_csv('raw_data/parte2.csv', sep=';', encoding = 'iso-8859-1')
    data3 = pd.read_csv('raw_data/parte3.csv', sep=';', encoding = 'iso-8859-1')
    data4 = pd.read_csv('raw_data/parte4.csv', sep=';', encoding = 'iso-8859-1')
    kept_columns = ['controle', 'titulo_do', 'total_rbft', 'cisp', 'data_fato', 'hora_fato', 'local', 'bairro_fato']
    eng_columns = ['Crime_ID', 'Crime_sub_type', 'Crime_type', 'Police_station', 'Date', 'Time', 'Place_type', 'Neighborhood']
    return data1, data2, data3, data4, kept_columns, eng_columns

# Import data with correct bairros and AR names
def get_bairros_data():
    bairros_all = pd.read_csv("raw_data/bairros_lista.csv", encoding='iso-8859-1')
    return bairros_all


# Cleaning function
def merge_clean(data1, data2, data3, data4):

    # Merging
    data = pd.concat([data1, data2, data3, data4]) # Merging all datasets

    # Focusing on Rio de Janeiro only
    data = data[data['municipio_fato'] == 'Rio de Janeiro (Capital)'] # Filtering on Rio de Janeiro only

    # Columns transforming
    data = data[kept_columns] # Removing useless columns
    data.columns = eng_columns  # Renaming columns in English

    # Date and Time preprocessing
    data = data[data['Time'] != '99'] # Removing invalid time format
    data['Date_Time'] = pd.to_datetime(data['Date'] + ' '
                                      + data['Time'], format='%Y-%m-%d %H:%M') # Passing to datetime format
    data.drop(columns=['Date', 'Time'], inplace=True) # Removing time and date columns once the Date_Time is created
    data = data[data['Date_Time'] > '2008-01-31'] # Removing irrelevant date samples

    # Missing values, duplicates & text standardizing
    data = data.drop_duplicates(subset="Crime_ID") # Removing duplicates
    data['Neighborhood'] = data['Neighborhood'].map(lambda x: unidecode.unidecode(x)) # Removing accents
    data = data[data['Neighborhood'] != 'sem informacao'] # Removing missing values for neighborhood

    return data

# Bairra detail
def barra_replace(row):
    if row == "Barra":
        row= "Barra da Tijuca"
    return row

# Bairros/AR matching
def get_AR(data, ar_data): #data_AR should be the full table with bairros and AR

    data['Neighborhood'] = data['Neighborhood'].map(barra_replace) # Setting the good "Barra da Tijuca" name

    # Bairros matching
    bairros = pd.DataFrame(ar_data, columns=["Bairro"]) # Creating a table with only the bairros
    bairros.set_index("Bairro")
    data = fuzzymatcher.fuzzy_left_join(data, bairros, left_on="Neighborhood", right_on="Bairro") # Replacing non-standardized bairros names with standardized ones
    data = data.drop(columns=['best_match_score', '__id_left', '__id_right', 'Neighborhood']) # Removing useless columns
    data.rename(columns={'Bairro': 'Neighborhood'}, inplace=True)
    data = pd.merge(data,ar_data,left_on='Neighborhood', right_on='Bairro',how='left').drop(columns=["Regiao","IDS","Bairro",'N¼']) # Aggreagting the right AR names to our new bairros
    data.rename(columns={'R.A': 'RA'}, inplace=True)
    data = data.dropna(subset='RA') # Removing lines with no bairros/AR information

    return data

# Cleaning - all
def clean_all(data1, data2, data3, data4, ar_data):
    data = merge_clean(data1, data2, data3, data4)
    data = get_AR(data, ar_data)

    return data

# %%
data1, data2, data3, data4, kept_columns, eng_columns = get_data()

# %%
data = merge_clean(data1, data2, data3, data4)

# %%
data.dtypes
# Out:
# Crime_ID                  object
# Crime_sub_type            object
# Crime_type                object
# Police_station            object
# Place_type                object
# Neighborhood              object
# Date_Time         datetime64[ns]
# dtype: object

# %%
data['Neighborhood'] = data['Neighborhood'].map(barra_replace)

# %%
get_bairros_data()
# Out:
#       N¼          Bairro              R.A      Regiao    IDS
# 0      1           Lagoa            Lagoa    Zona Sul  0.854
# 1      2          Leblon            Lagoa    Zona Sul  0,809
# 2      3         Ipanema            Lagoa    Zona Sul  0,801
# 3      4         Humaita         Botafogo    Zona Sul  0,798
# 4      5            Urca         Botafogo    Zona Sul  0,795
# ..   ...             ...              ...         ...    ...
# 153  154       Guaratiba        Guaratiba  Zona Oeste  0,433
# 154  155  Vargem Pequena  Barra da Tijuca  Zona Oeste  0,425
# 155  156   Vargem Grande  Barra da Tijuca  Zona Oeste  0,408
# 156  157         Camorim      Jacarepagua  Zona Oeste  0,369
# 157  158         Grumari  Barra da Tijuca  Zona Oeste  0,277
#
# [158 rows x 5 columns]

# %%
bairros = pd.DataFrame(get_bairros_data(), columns=["Bairro"]) # Creating a table with only the bairros

# %%
bairros
# Out:
#              Bairro
# 0             Lagoa
# 1            Leblon
# 2           Ipanema
# 3           Humaita
# 4              Urca
# ..              ...
# 153       Guaratiba
# 154  Vargem Pequena
# 155   Vargem Grande
# 156         Camorim
# 157         Grumari
#
# [158 rows x 1 columns]

# %%
bairros.set_index("Bairro")
# Out:
# Empty DataFrame
# Columns: []
# Index: [Lagoa, Leblon, Ipanema, Humaita, Urca, Barra da Tijuca, Jardim Botanico, Sao Conrado, Gavea, Laranjeiras, Flamengo, Leme, Maracana, Copacabana, Jardim Guanabara, Botafogo, Campo dos Afonsos, Tijuca, Grajau, Meier, Monero, Cosme Velho, Joa, Todos os Santos, Gloria, Andarai, Ribeira, Vila Isabel, Zumbi, Rocha, Praca da Bandeira, Cachambi, Riachuelo, Cocota, Vila Valqueire, Vila da Penha, Catete, Pechincha, Freguesia (Jacarepagua), Praia da Bandeira, Maria da Graca, Sao Francisco Xavier, Anil, Higienopolis, Vista Alegre, Portuguesa, Centro, Jardim Sulacap, Abolicao, Rio Comprido, Engenho Novo, Freguesia (Ilha do Governador), Encantado, Bonsucesso, Lins de Vasconcellos, Recreio dos Bandeirantes, Vila Cosmos, Engenho de Dentro, Ramos, Santa Teresa, Taquara, Iraja, Quintino Bocaiuva, agua Santa, Olaria, Piedade, Jardim Carioca, Bancarios, Praca Seca, Saude, Tanque, Vila Militar, Campinho, Sao Cristovao, Paqueta, Penha Circular, Oswaldo Cruz, Jacare, Bento Ribeiro, Cascadura, Bras de Pina, Madureira, Pilares, Vaz Lobo, Engenho da Rainha, Penha, Cacuia, Pitangueiras, Marechal Hermes, Tomas Coelho, Sampaio, Estacio, Santo Cristo, Cidade Universitaria, Cavalcanti, Jardim America, Taua, Inhauma, Benfica, Catumbi, ...]
#
# [158 rows x 0 columns]

# %%
data = fuzzymatcher.fuzzy_left_join(data, bairros, left_on="Neighborhood", right_on="Bairro") # Replacing non-standardized bairros names with standardized ones

# %%
data = data.drop(columns=['best_match_score', '__id_left', '__id_right', 'Neighborhood']) # Removing useless columns

# %%
data.rename(columns={'Bairro': 'Neighborhood'}, inplace=True)

# %%
data = pd.merge(data,get_bairros_data(),left_on='Neighborhood', right_on='Bairro',how='left').drop(columns=["Regiao","IDS","Bairro",'N¼']) # Aggreagting the right AR names to our new bairros

# %%
data.rename(columns={'R.A': 'RA'}, inplace=True)

# %%
data = data.dropna(subset=['RA']) # Removing lines with no bairros/AR information

# %%
data
# Out:
#               Crime_ID         Crime_sub_type     Crime_type  \
# 0        00787401-2009  Lesão corporal dolosa  Não se aplica
# 1        01137431-2009  Lesão corporal dolosa  Não se aplica
# 2        02023941-2009  Lesão corporal dolosa  Não se aplica
# 4        04751871-2009  Lesão corporal dolosa  Não se aplica
# 5        04909311-2009                 Ameaça  Não se aplica
# ...                ...                    ...            ...
# 1220307  96730181-2019      Roubo em coletivo          Roubo
# 1220308  97578571-2019     Furto a transeunte          Furto
# 1220309  98313421-2019     Furto a transeunte          Furto
# 1220310  98452031-2019     Furto a transeunte          Furto
# 1220311  98535391-2019     Furto a transeunte          Furto
#
#                     Police_station            Place_type           Date_Time  \
# 0         043a. Pedra de Guaratiba                 Praia 2009-01-01 04:30:00
# 1               035a. Campo Grande            Residência 2009-01-01 19:00:00
# 2             040a. Honório Gurgel            Residência 2008-12-31 20:30:00
# 4               035a. Campo Grande           Via pública 2009-01-01 01:30:00
# 5                     039a. Pavuna            Residência 2009-01-01 03:03:00
# ...                            ...                   ...                 ...
# 1220307  027a. Vicente de Carvalho  Interior de coletivo 2019-12-19 20:55:00
# 1220308           012a. Copacabana                 Praia 2019-12-31 17:00:00
# 1220309           012a. Copacabana           Via pública 2019-12-29 19:00:00
# 1220310               014a. Leblon  Interior de coletivo 2019-12-30 11:45:00
# 1220311   004a. Praça da República   Estação metroviária 2019-12-31 19:00:00
#
#                    Neighborhood            RA
# 0            Pedra de Guaratiba     Guaratiba
# 1                    Santissimo  Campo Grande
# 2                Honorio Gurgel     Madureira
# 4                  Campo Grande  Campo Grande
# 5        Ricardo de Albuquerque      Anchieta
# ...                         ...           ...
# 1220307                   Iraja         Iraja
# 1220308              Copacabana    Copacabana
# 1220309              Copacabana    Copacabana
# 1220310                  Centro        Centro
# 1220311                  Centro        Centro
#
# [1189412 rows x 8 columns]

# %%
data.Date_Time.isnull().sum()
# Out:
# 0

# %%
data
# Out:
#               Crime_ID         Crime_sub_type     Crime_type  \
# 0        00787401-2009  Lesão corporal dolosa  Não se aplica
# 1        01137431-2009  Lesão corporal dolosa  Não se aplica
# 2        02023941-2009  Lesão corporal dolosa  Não se aplica
# 4        04751871-2009  Lesão corporal dolosa  Não se aplica
# 5        04909311-2009                 Ameaça  Não se aplica
# ...                ...                    ...            ...
# 1220307  96730181-2019      Roubo em coletivo          Roubo
# 1220308  97578571-2019     Furto a transeunte          Furto
# 1220309  98313421-2019     Furto a transeunte          Furto
# 1220310  98452031-2019     Furto a transeunte          Furto
# 1220311  98535391-2019     Furto a transeunte          Furto
#
#                     Police_station            Place_type           Date_Time  \
# 0         043a. Pedra de Guaratiba                 Praia 2009-01-01 04:30:00
# 1               035a. Campo Grande            Residência 2009-01-01 19:00:00
# 2             040a. Honório Gurgel            Residência 2008-12-31 20:30:00
# 4               035a. Campo Grande           Via pública 2009-01-01 01:30:00
# 5                     039a. Pavuna            Residência 2009-01-01 03:03:00
# ...                            ...                   ...                 ...
# 1220307  027a. Vicente de Carvalho  Interior de coletivo 2019-12-19 20:55:00
# 1220308           012a. Copacabana                 Praia 2019-12-31 17:00:00
# 1220309           012a. Copacabana           Via pública 2019-12-29 19:00:00
# 1220310               014a. Leblon  Interior de coletivo 2019-12-30 11:45:00
# 1220311   004a. Praça da República   Estação metroviária 2019-12-31 19:00:00
#
#                    Neighborhood            RA
# 0            Pedra de Guaratiba     Guaratiba
# 1                    Santissimo  Campo Grande
# 2                Honorio Gurgel     Madureira
# 4                  Campo Grande  Campo Grande
# 5        Ricardo de Albuquerque      Anchieta
# ...                         ...           ...
# 1220307                   Iraja         Iraja
# 1220308              Copacabana    Copacabana
# 1220309              Copacabana    Copacabana
# 1220310                  Centro        Centro
# 1220311                  Centro        Centro
#
# [1189412 rows x 8 columns]

# %%
from pop_data import clean_pop_data

# %%
pop_data = clean_pop_data()

# %%
pop_data
# Out:
#       Ano  Populacao administrative_regions
# 0    2000    39973.0              Portuaria
# 1    2001    39246.0              Portuaria
# 2    2002    38519.0              Portuaria
# 3    2003    37792.0              Portuaria
# 4    2004    37065.0              Portuaria
# ..    ...        ...                    ...
# 667  2016    32933.8         Cidade de Deus
# 668  2017    32610.6         Cidade de Deus
# 669  2018    32287.4         Cidade de Deus
# 670  2019    31964.2         Cidade de Deus
# 671  2020    31641.0         Cidade de Deus
#
# [672 rows x 3 columns]

# %%
data['Year'] = pd.DatetimeIndex(data.Date_Time).year
# Out:
# /var/folders/7b/hgztdlzd4k76rwydg33k1vhm0000gn/T/ipykernel_54361/4142032728.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Year'] = pd.DatetimeIndex(data.Date_Time).year

# %%
data
# Out:
#               Crime_ID         Crime_sub_type     Crime_type  \
# 0        00787401-2009  Lesão corporal dolosa  Não se aplica
# 1        01137431-2009  Lesão corporal dolosa  Não se aplica
# 2        02023941-2009  Lesão corporal dolosa  Não se aplica
# 4        04751871-2009  Lesão corporal dolosa  Não se aplica
# 5        04909311-2009                 Ameaça  Não se aplica
# ...                ...                    ...            ...
# 1220307  96730181-2019      Roubo em coletivo          Roubo
# 1220308  97578571-2019     Furto a transeunte          Furto
# 1220309  98313421-2019     Furto a transeunte          Furto
# 1220310  98452031-2019     Furto a transeunte          Furto
# 1220311  98535391-2019     Furto a transeunte          Furto
#
#                     Police_station            Place_type           Date_Time  \
# 0         043a. Pedra de Guaratiba                 Praia 2009-01-01 04:30:00
# 1               035a. Campo Grande            Residência 2009-01-01 19:00:00
# 2             040a. Honório Gurgel            Residência 2008-12-31 20:30:00
# 4               035a. Campo Grande           Via pública 2009-01-01 01:30:00
# 5                     039a. Pavuna            Residência 2009-01-01 03:03:00
# ...                            ...                   ...                 ...
# 1220307  027a. Vicente de Carvalho  Interior de coletivo 2019-12-19 20:55:00
# 1220308           012a. Copacabana                 Praia 2019-12-31 17:00:00
# 1220309           012a. Copacabana           Via pública 2019-12-29 19:00:00
# 1220310               014a. Leblon  Interior de coletivo 2019-12-30 11:45:00
# 1220311   004a. Praça da República   Estação metroviária 2019-12-31 19:00:00
#
#                    Neighborhood            RA  Year
# 0            Pedra de Guaratiba     Guaratiba  2009
# 1                    Santissimo  Campo Grande  2009
# 2                Honorio Gurgel     Madureira  2008
# 4                  Campo Grande  Campo Grande  2009
# 5        Ricardo de Albuquerque      Anchieta  2009
# ...                         ...           ...   ...
# 1220307                   Iraja         Iraja  2019
# 1220308              Copacabana    Copacabana  2019
# 1220309              Copacabana    Copacabana  2019
# 1220310                  Centro        Centro  2019
# 1220311                  Centro        Centro  2019
#
# [1189412 rows x 9 columns]

# %%
data_merge = pd.merge(left=data, right=pop_data, left_on=["RA","Year"],right_on=["administrative_regions", "Ano"])

# %%
data_merge
# Out:
#               Crime_ID                      Crime_sub_type     Crime_type  \
# 0        00787401-2009               Lesão corporal dolosa  Não se aplica
# 1        07177211-2009  Lesão corporal culposa de trânsito  Não se aplica
# 2        21813091-2009                              Ameaça  Não se aplica
# 3        37974231-2009               Lesão corporal dolosa  Não se aplica
# 4        73801671-2009               Lesão corporal dolosa  Não se aplica
# ...                ...                                 ...            ...
# 1135254  70645371-2019                   Furto de veículos          Furto
# 1135255  42741691-2019                    Homicídio doloso  Não se aplica
# 1135256  18847651-2019                  Furto a transeunte          Furto
# 1135257  68517021-2019           Furto de telefone celular          Furto
# 1135258  64044451-2019           Furto de telefone celular          Furto
#
#                    Police_station                     Place_type  \
# 0        043a. Pedra de Guaratiba                          Praia
# 1           016a. Barra da Tijuca                    Via pública
# 2        043a. Pedra de Guaratiba                     Residência
# 3        043a. Pedra de Guaratiba                    Via pública
# 4        043a. Pedra de Guaratiba                     Residência
# ...                           ...                            ...
# 1135254          021a. Bonsucesso                    Via pública
# 1135255        025a. Engenho Novo  Hospital, clínica e similares
# 1135256        025a. Engenho Novo                         Favela
# 1135257          021a. Bonsucesso           Interior de coletivo
# 1135258              009a. Catete                    Via pública
#
#                   Date_Time        Neighborhood           RA  Year   Ano  \
# 0       2009-01-01 04:30:00  Pedra de Guaratiba    Guaratiba  2009  2009
# 1       2009-01-01 19:10:00  Barra de Guaratiba    Guaratiba  2009  2009
# 2       2009-01-01 05:30:00           Guaratiba    Guaratiba  2009  2009
# 3       2009-01-01 19:30:00           Guaratiba    Guaratiba  2009  2009
# 4       2009-01-01 03:40:00  Barra de Guaratiba    Guaratiba  2009  2009
# ...                     ...                 ...          ...   ...   ...
# 1135254 2019-07-08 05:00:00         Jacarezinho  Jacarezinho  2019  2019
# 1135255 2019-09-01 02:49:00         Jacarezinho  Jacarezinho  2019  2019
# 1135256 2019-11-25 01:25:00         Jacarezinho  Jacarezinho  2019  2019
# 1135257 2019-12-18 14:20:00         Jacarezinho  Jacarezinho  2019  2019
# 1135258 2020-01-01 00:30:00            Flamengo     Botafogo  2020  2020
#
#          Populacao administrative_regions
# 0         131901.6              Guaratiba
# 1         131901.6              Guaratiba
# 2         131901.6              Guaratiba
# 3         131901.6              Guaratiba
# 4         131901.6              Guaratiba
# ...            ...                    ...
# 1135254    24065.0            Jacarezinho
# 1135255    24065.0            Jacarezinho
# 1135256    24065.0            Jacarezinho
# 1135257    24065.0            Jacarezinho
# 1135258   178122.0               Botafogo
#
# [1135259 rows x 12 columns]

# %%
data_merge.drop(columns=["administrative_regions","Ano","Year"], inplace = True)

# %%
data_merge
# Out:
#               Crime_ID                      Crime_sub_type     Crime_type  \
# 0        00787401-2009               Lesão corporal dolosa  Não se aplica
# 1        07177211-2009  Lesão corporal culposa de trânsito  Não se aplica
# 2        21813091-2009                              Ameaça  Não se aplica
# 3        37974231-2009               Lesão corporal dolosa  Não se aplica
# 4        73801671-2009               Lesão corporal dolosa  Não se aplica
# ...                ...                                 ...            ...
# 1135254  70645371-2019                   Furto de veículos          Furto
# 1135255  42741691-2019                    Homicídio doloso  Não se aplica
# 1135256  18847651-2019                  Furto a transeunte          Furto
# 1135257  68517021-2019           Furto de telefone celular          Furto
# 1135258  64044451-2019           Furto de telefone celular          Furto
#
#                    Police_station                     Place_type  \
# 0        043a. Pedra de Guaratiba                          Praia
# 1           016a. Barra da Tijuca                    Via pública
# 2        043a. Pedra de Guaratiba                     Residência
# 3        043a. Pedra de Guaratiba                    Via pública
# 4        043a. Pedra de Guaratiba                     Residência
# ...                           ...                            ...
# 1135254          021a. Bonsucesso                    Via pública
# 1135255        025a. Engenho Novo  Hospital, clínica e similares
# 1135256        025a. Engenho Novo                         Favela
# 1135257          021a. Bonsucesso           Interior de coletivo
# 1135258              009a. Catete                    Via pública
#
#                   Date_Time        Neighborhood           RA  Populacao
# 0       2009-01-01 04:30:00  Pedra de Guaratiba    Guaratiba   131901.6
# 1       2009-01-01 19:10:00  Barra de Guaratiba    Guaratiba   131901.6
# 2       2009-01-01 05:30:00           Guaratiba    Guaratiba   131901.6
# 3       2009-01-01 19:30:00           Guaratiba    Guaratiba   131901.6
# 4       2009-01-01 03:40:00  Barra de Guaratiba    Guaratiba   131901.6
# ...                     ...                 ...          ...        ...
# 1135254 2019-07-08 05:00:00         Jacarezinho  Jacarezinho    24065.0
# 1135255 2019-09-01 02:49:00         Jacarezinho  Jacarezinho    24065.0
# 1135256 2019-11-25 01:25:00         Jacarezinho  Jacarezinho    24065.0
# 1135257 2019-12-18 14:20:00         Jacarezinho  Jacarezinho    24065.0
# 1135258 2020-01-01 00:30:00            Flamengo     Botafogo   178122.0
#
# [1135259 rows x 9 columns]

# %%
data_merge_centro = data_merge[data_merge.RA == "Centro"]

# %%
data_merge_centro
# Out:
#               Crime_ID         Crime_sub_type     Crime_type  \
# 38689    35291951-2009                 Ameaça  Não se aplica
# 38690    79232411-2009                 Ameaça  Não se aplica
# 38691    33711511-2009  Lesão corporal dolosa  Não se aplica
# 38692    08528251-2009                 Ameaça  Não se aplica
# 38693    86839681-2009                 Ameaça  Não se aplica
# ...                ...                    ...            ...
# 1098073  67853881-2019     Furto a transeunte          Furto
# 1098074  76335831-2019     Furto a transeunte          Furto
# 1098075  82480471-2019     Furto a transeunte          Furto
# 1098076  98452031-2019     Furto a transeunte          Furto
# 1098077  98535391-2019     Furto a transeunte          Furto
#
#                    Police_station                 Place_type  \
# 38689             005a. Mem de Sá  Estabelecimento comercial
# 38690    004a. Praça da República  Estabelecimento comercial
# 38691    004a. Praça da República                Via pública
# 38692             005a. Mem de Sá                 Escritório
# 38693    004a. Praça da República                     Outros
# ...                           ...                        ...
# 1098073           005a. Mem de Sá                Via pública
# 1098074           005a. Mem de Sá                Via pública
# 1098075           005a. Mem de Sá                Via pública
# 1098076              014a. Leblon       Interior de coletivo
# 1098077  004a. Praça da República        Estação metroviária
#
#                   Date_Time Neighborhood      RA  Populacao
# 38689   2008-12-31 15:00:00       Centro  Centro    30022.4
# 38690   2008-11-07 16:00:00       Centro  Centro    30022.4
# 38691   2008-12-29 10:05:00       Centro  Centro    30022.4
# 38692   2008-12-23 09:00:00       Centro  Centro    30022.4
# 38693   2008-12-30 00:00:00       Centro  Centro    30022.4
# ...                     ...          ...     ...        ...
# 1098073 2019-12-30 21:00:00       Centro  Centro    20590.8
# 1098074 2019-12-29 03:30:00       Centro  Centro    20590.8
# 1098075 2019-12-31 09:00:00       Centro  Centro    20590.8
# 1098076 2019-12-30 11:45:00       Centro  Centro    20590.8
# 1098077 2019-12-31 19:00:00       Centro  Centro    20590.8
#
# [94888 rows x 9 columns]

# %%
data_merge_centro["year"] = pd.DatetimeIndex(data_merge_centro.Date_Time).year
# Out:
# /var/folders/7b/hgztdlzd4k76rwydg33k1vhm0000gn/T/ipykernel_54361/269281284.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_merge_centro["year"] = pd.DatetimeIndex(data_merge_centro.Date_Time).year

# %%
data_merge_centro2 = data_merge_centro.groupby("year").mean()

# %%
data_merge_centro2.reset_index(inplace=True)

# %%
data_merge_centro2
# Out:
#     year  Populacao
# 0   2008    30022.4
# 1   2009    28997.2
# 2   2010    27972.0
# 3   2011    27097.2
# 4   2012    26222.4
# 5   2013    25347.6
# 6   2014    24472.8
# 7   2015    23598.0
# 8   2016    22846.2
# 9   2017    22094.4
# 10  2018    21342.6
# 11  2019    20590.8

# %%
plt.plot(data_merge_centro2.year, data_merge_centro2.Populacao)

# %%
pop_data_centro = pop_data[pop_data.administrative_regions == "Centro"]

# %%
pop_data_centro
# Out:
#      Ano  Populacao administrative_regions
# 21  2000    39135.0                 Centro
# 22  2001    37927.6                 Centro
# 23  2002    36720.2                 Centro
# 24  2003    35512.8                 Centro
# 25  2004    34305.4                 Centro
# 26  2005    33098.0                 Centro
# 27  2006    32072.8                 Centro
# 28  2007    31047.6                 Centro
# 29  2008    30022.4                 Centro
# 30  2009    28997.2                 Centro
# 31  2010    27972.0                 Centro
# 32  2011    27097.2                 Centro
# 33  2012    26222.4                 Centro
# 34  2013    25347.6                 Centro
# 35  2014    24472.8                 Centro
# 36  2015    23598.0                 Centro
# 37  2016    22846.2                 Centro
# 38  2017    22094.4                 Centro
# 39  2018    21342.6                 Centro
# 40  2019    20590.8                 Centro
# 41  2020    19839.0                 Centro

# %%
plt.plot(pop_data_centro.Ano, pop_data_centro.Populacao)
plt.plot(data_merge_centro2.year, data_merge_centro2.Populacao)

# %%
import clean2
from datetime import datetime

# %%
print("start time  =", datetime.now())
print("************* QC get_data() *************************")
data1, data2, data3, data4 = clean2.get_data()
print(data1.head())
print("************* QC get_bairros_data() *****************")
bairros_all = clean2.get_bairros_data()
print(bairros_all.head())
print("************* QC merge_clean() **********************")
data = clean2.merge_clean(data1, data2, data3, data4)
print(data.head())
print("************* QC get_AR() ***************************")
rio_df = clean2.get_AR(data, bairros_all)
print(rio_df.head())
#data = clean_all(data1, data2, data3, data4, get_bairros_data())
#print(data.head(5))
print("end time  =", datetime.now())
# Out:
# start time  = 2022-03-01 21:13:27.793941
# ************* QC get_data() *************************
#         controle   ano      mes              titulo_do     total_rbft  \
# 0  00787401-2009  2009  Janeiro  Lesão corporal dolosa  Não se aplica
# 1  00908861-2009  2009  Janeiro  Lesão corporal dolosa  Não se aplica
# 2  00954561-2009  2009  Janeiro  Lesão corporal dolosa  Não se aplica
# 3  00987771-2009  2009  Janeiro  Lesão corporal dolosa  Não se aplica
# 4  00987771-2009  2009  Janeiro  Lesão corporal dolosa  Não se aplica
#
#   conteudo                                                 dp  \
# 0  vítimas                           043a. Pedra de Guaratiba
# 1  vítimas                                   119a. Rio Bonito
# 2  vítimas  Delegacia de Atendimento à Mulher - Volta Redonda
# 3  vítimas                            145a. São João da Barra
# 4  vítimas                            145a. São João da Barra
#
#                        cisp    data_com   data_fato  ...     risp  \
# 0  043a. Pedra de Guaratiba  2009-01-01  2009-01-01  ...  RISP 02
# 1          119a. Rio Bonito  2009-01-01  2008-12-31  ...  RISP 04
# 2         090a. Barra Mansa  2009-01-01  2009-01-01  ...  RISP 05
# 3   145a. São João da Barra  2009-01-01  2009-01-01  ...  RISP 06
# 4   145a. São João da Barra  2009-01-01  2009-01-01  ...  RISP 06
#
#          local            sexo   data_nasc             cor    profissao  \
# 0        Praia       masculino  1992-09-02           parda    Estudante
# 1  Via pública  sem informação  1979-06-20  sem informação    Cantor(a)
# 2  Via pública        feminino  1966-03-28           parda     Ignorado
# 3  Via pública        feminino  1988-09-28          branca    Estudante
# 4  Via pública       masculino  1988-09-28          branca  Carteiro(a)
#
#     relacao          bairro_vit      municipio_vit idade
# 0  Ignorado          SANTA CRUZ     RIO DE JANEIRO  16.0
# 1     Outra      SERRA DO SAMBE         RIO BONITO  29.0
# 2     Genro  COLÔNIA S. ANTONIO        BARRA MANSA  42.0
# 3     Outra           TURF CLUB             CAMPOS  20.0
# 4     Outra              CENTRO  SAO JOAO DA BARRA  20.0
#
# [5 rows x 25 columns]
# ************* QC get_bairros_data() *****************
#    N¼   Bairro       R.A    Regiao    IDS
# 0   1    Lagoa     Lagoa  Zona Sul  0.854
# 1   2   Leblon     Lagoa  Zona Sul  0,809
# 2   3  Ipanema     Lagoa  Zona Sul  0,801
# 3   4  Humaita  Botafogo  Zona Sul  0,798
# 4   5     Urca  Botafogo  Zona Sul  0,795
# ************* QC merge_clean() **********************
#          Crime_ID         Crime_sub_type     Crime_type  \
# 0   00787401-2009  Lesão corporal dolosa  Não se aplica
# 5   01137431-2009  Lesão corporal dolosa  Não se aplica
# 9   02023941-2009  Lesão corporal dolosa  Não se aplica
# 15  02646521-2009  Lesão corporal dolosa  Não se aplica
# 19  04751871-2009  Lesão corporal dolosa  Não se aplica
#
#               Police_station   Place_type                    Neighborhood  \
# 0   043a. Pedra de Guaratiba        Praia  PRAIA DA BRISA/PEDRA DE GUARAT
# 5         035a. Campo Grande   Residência                      SANTISSIMO
# 9       040a. Honório Gurgel   Residência                  HONORIO GURGEL
# 15        035a. Campo Grande   Residência                     VASCONCELOS
# 19        035a. Campo Grande  Via pública                    CAMPO GRANDE
#
#              Date_Time
# 0  2009-01-01 04:30:00
# 5  2009-01-01 19:00:00
# 9  2008-12-31 20:30:00
# 15 2009-01-01 19:00:00
# 19 2009-01-01 01:30:00
# ************* QC get_AR() ***************************
#     best_match_score __id_left __id_right       Crime_ID  \
# 0          -0.214711    0_left  114_right  00787401-2009
# 16          0.162033    1_left  139_right  01137431-2009
# 17          0.405996    2_left  107_right  02023941-2009
# 18               NaN    3_left       None  02646521-2009
# 19          0.278060    4_left  128_right  04751871-2009
#
#            Crime_sub_type     Crime_type            Police_station  \
# 0   Lesão corporal dolosa  Não se aplica  043a. Pedra de Guaratiba
# 16  Lesão corporal dolosa  Não se aplica        035a. Campo Grande
# 17  Lesão corporal dolosa  Não se aplica      040a. Honório Gurgel
# 18  Lesão corporal dolosa  Não se aplica        035a. Campo Grande
# 19  Lesão corporal dolosa  Não se aplica        035a. Campo Grande
#
#      Place_type                    Neighborhood           Date_Time  \
# 0         Praia  PRAIA DA BRISA/PEDRA DE GUARAT 2009-01-01 04:30:00
# 16   Residência                      SANTISSIMO 2009-01-01 19:00:00
# 17   Residência                  HONORIO GURGEL 2008-12-31 20:30:00
# 18   Residência                     VASCONCELOS 2009-01-01 19:00:00
# 19  Via pública                    CAMPO GRANDE 2009-01-01 01:30:00
#
#                 Bairro
# 0   Pedra de Guaratiba
# 16          Santissimo
# 17      Honorio Gurgel
# 18                 NaN
# 19        Campo Grande
# end time  = 2022-03-01 21:22:46.588555

# %%
rio_df
# Out:
#          best_match_score     __id_left __id_right       Crime_ID  \
# 0               -0.214711        0_left  114_right  00787401-2009
# 16               0.162033        1_left  139_right  01137431-2009
# 17               0.405996        2_left  107_right  02023941-2009
# 18                    NaN        3_left       None  02646521-2009
# 19               0.278060        4_left  128_right  04751871-2009
# ...                   ...           ...        ...            ...
# 1405233          0.243963  1220307_left   61_right  96730181-2019
# 1405234          0.162033  1220308_left   13_right  97578571-2019
# 1405235          0.162033  1220309_left   13_right  98313421-2019
# 1405236          0.146129  1220310_left   46_right  98452031-2019
# 1405237          0.146129  1220311_left   46_right  98535391-2019
#
#                 Crime_sub_type     Crime_type             Police_station  \
# 0        Lesão corporal dolosa  Não se aplica   043a. Pedra de Guaratiba
# 16       Lesão corporal dolosa  Não se aplica         035a. Campo Grande
# 17       Lesão corporal dolosa  Não se aplica       040a. Honório Gurgel
# 18       Lesão corporal dolosa  Não se aplica         035a. Campo Grande
# 19       Lesão corporal dolosa  Não se aplica         035a. Campo Grande
# ...                        ...            ...                        ...
# 1405233      Roubo em coletivo          Roubo  027a. Vicente de Carvalho
# 1405234     Furto a transeunte          Furto           012a. Copacabana
# 1405235     Furto a transeunte          Furto           012a. Copacabana
# 1405236     Furto a transeunte          Furto               014a. Leblon
# 1405237     Furto a transeunte          Furto   004a. Praça da República
#
#                    Place_type                    Neighborhood  \
# 0                       Praia  PRAIA DA BRISA/PEDRA DE GUARAT
# 16                 Residência                      SANTISSIMO
# 17                 Residência                  HONORIO GURGEL
# 18                 Residência                     VASCONCELOS
# 19                Via pública                    CAMPO GRANDE
# ...                       ...                             ...
# 1405233  Interior de coletivo                           Iraja
# 1405234                 Praia                      Copacabana
# 1405235           Via pública                      Copacabana
# 1405236  Interior de coletivo                          Centro
# 1405237   Estação metroviária                          Centro
#
#                   Date_Time              Bairro
# 0       2009-01-01 04:30:00  Pedra de Guaratiba
# 16      2009-01-01 19:00:00          Santissimo
# 17      2008-12-31 20:30:00      Honorio Gurgel
# 18      2009-01-01 19:00:00                 NaN
# 19      2009-01-01 01:30:00        Campo Grande
# ...                     ...                 ...
# 1405233 2019-12-19 20:55:00               Iraja
# 1405234 2019-12-31 17:00:00          Copacabana
# 1405235 2019-12-29 19:00:00          Copacabana
# 1405236 2019-12-30 11:45:00              Centro
# 1405237 2019-12-31 19:00:00              Centro
#
# [1220312 rows x 11 columns]

# %%
rio_df = rio_df.drop(columns=["best_match_score",\
        "__id_left", "__id_right", "Neighborhood"]) # Removing useless columns

# %%
rio_df.rename(columns={"Bairro": "Neighborhood"}, inplace=True)

# %%
rio_df = pd.merge(rio_df,bairros_all,left_on="Neighborhood",\
        right_on="Bairro",how="left").drop(columns=["Regiao","IDS","Bairro","N¼"]) # Aggreagting the right AR names to our new bairros

# %%
rio_df
# Out:
#               Crime_ID         Crime_sub_type     Crime_type  \
# 0        00787401-2009  Lesão corporal dolosa  Não se aplica
# 1        01137431-2009  Lesão corporal dolosa  Não se aplica
# 2        02023941-2009  Lesão corporal dolosa  Não se aplica
# 3        02646521-2009  Lesão corporal dolosa  Não se aplica
# 4        04751871-2009  Lesão corporal dolosa  Não se aplica
# ...                ...                    ...            ...
# 1220307  96730181-2019      Roubo em coletivo          Roubo
# 1220308  97578571-2019     Furto a transeunte          Furto
# 1220309  98313421-2019     Furto a transeunte          Furto
# 1220310  98452031-2019     Furto a transeunte          Furto
# 1220311  98535391-2019     Furto a transeunte          Furto
#
#                     Police_station            Place_type           Date_Time  \
# 0         043a. Pedra de Guaratiba                 Praia 2009-01-01 04:30:00
# 1               035a. Campo Grande            Residência 2009-01-01 19:00:00
# 2             040a. Honório Gurgel            Residência 2008-12-31 20:30:00
# 3               035a. Campo Grande            Residência 2009-01-01 19:00:00
# 4               035a. Campo Grande           Via pública 2009-01-01 01:30:00
# ...                            ...                   ...                 ...
# 1220307  027a. Vicente de Carvalho  Interior de coletivo 2019-12-19 20:55:00
# 1220308           012a. Copacabana                 Praia 2019-12-31 17:00:00
# 1220309           012a. Copacabana           Via pública 2019-12-29 19:00:00
# 1220310               014a. Leblon  Interior de coletivo 2019-12-30 11:45:00
# 1220311   004a. Praça da República   Estação metroviária 2019-12-31 19:00:00
#
#                Neighborhood           R.A
# 0        Pedra de Guaratiba     Guaratiba
# 1                Santissimo  Campo Grande
# 2            Honorio Gurgel     Madureira
# 3                       NaN           NaN
# 4              Campo Grande  Campo Grande
# ...                     ...           ...
# 1220307               Iraja         Iraja
# 1220308          Copacabana    Copacabana
# 1220309          Copacabana    Copacabana
# 1220310              Centro        Centro
# 1220311              Centro        Centro
#
# [1220312 rows x 8 columns]

# %%
rio_df.rename(columns={"R.A": "RA"}, inplace=True)
rio_df = rio_df_2.dropna(subset=["RA"]) # Removing lines with no bairros/AR information

# %%
rio_df
# Out:
#               Crime_ID         Crime_sub_type     Crime_type  \
# 0        00787401-2009  Lesão corporal dolosa  Não se aplica
# 1        01137431-2009  Lesão corporal dolosa  Não se aplica
# 2        02023941-2009  Lesão corporal dolosa  Não se aplica
# 4        04751871-2009  Lesão corporal dolosa  Não se aplica
# 5        04909311-2009                 Ameaça  Não se aplica
# ...                ...                    ...            ...
# 1220307  96730181-2019      Roubo em coletivo          Roubo
# 1220308  97578571-2019     Furto a transeunte          Furto
# 1220309  98313421-2019     Furto a transeunte          Furto
# 1220310  98452031-2019     Furto a transeunte          Furto
# 1220311  98535391-2019     Furto a transeunte          Furto
#
#                     Police_station            Place_type           Date_Time  \
# 0         043a. Pedra de Guaratiba                 Praia 2009-01-01 04:30:00
# 1               035a. Campo Grande            Residência 2009-01-01 19:00:00
# 2             040a. Honório Gurgel            Residência 2008-12-31 20:30:00
# 4               035a. Campo Grande           Via pública 2009-01-01 01:30:00
# 5                     039a. Pavuna            Residência 2009-01-01 03:03:00
# ...                            ...                   ...                 ...
# 1220307  027a. Vicente de Carvalho  Interior de coletivo 2019-12-19 20:55:00
# 1220308           012a. Copacabana                 Praia 2019-12-31 17:00:00
# 1220309           012a. Copacabana           Via pública 2019-12-29 19:00:00
# 1220310               014a. Leblon  Interior de coletivo 2019-12-30 11:45:00
# 1220311   004a. Praça da República   Estação metroviária 2019-12-31 19:00:00
#
#                    Neighborhood            RA
# 0            Pedra de Guaratiba     Guaratiba
# 1                    Santissimo  Campo Grande
# 2                Honorio Gurgel     Madureira
# 4                  Campo Grande  Campo Grande
# 5        Ricardo de Albuquerque      Anchieta
# ...                         ...           ...
# 1220307                   Iraja         Iraja
# 1220308              Copacabana    Copacabana
# 1220309              Copacabana    Copacabana
# 1220310                  Centro        Centro
# 1220311                  Centro        Centro
#
# [1189412 rows x 8 columns]

# %%
# Import section
from datetime import datetime
from webbrowser import get
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import clean

# %%
clean.get_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/7b/hgztdlzd4k76rwydg33k1vhm0000gn/T/ipykernel_54361/3506246019.py in <module>
# ----> 1 clean.get_data()
#
# AttributeError: module 'clean' has no attribute 'get_data'

# %%
pop_raw = get_popfile()

# %%
pop_raw
# Out:
#       RegiaoAdministrativa   Ano  Populacao DensidadeBruta DensidadeLiquida  \
# 0             I  Portuaria  2000      39973           47,0             47,1
# 1             I  Portuaria  2005      36338           42,7             42,8
# 2             I  Portuaria  2010      32999           38,8             38,9
# 3             I  Portuaria  2015      29905           35,1             35,2
# 4             I  Portuaria  2020      27001           31,7             31,8
# ..                     ...   ...        ...            ...              ...
# 155  XXXIV  Cidade de Deus  2000      38016          315,3            315,3
# 156  XXXIV  Cidade de Deus  2005      36405          301,9            301,9
# 157  XXXIV  Cidade de Deus  2010       3483          288,9            288,9
# 158  XXXIV  Cidade de Deus  2015      33257          275,8            275,8
# 159  XXXIV  Cidade de Deus  2020      31641          262,4            262,4
#
#     TaxaGeometrica
# 0            1,89%
# 1            1,91%
# 2            1,95%
# 3            2,02%
# 4              NaN
# ..             ...
# 155          0,86%
# 156          0,88%
# 157          0,92%
# 158          0,99%
# 159            NaN
#
# [160 rows x 6 columns]

# %%
pop_clean = clean_pop_data()

# %%
pop_clean
# Out:
#       Ano  Populacao administrative_regions
# 0    2000    39973.0              Portuaria
# 1    2001    39246.0              Portuaria
# 2    2002    38519.0              Portuaria
# 3    2003    37792.0              Portuaria
# 4    2004    37065.0              Portuaria
# ..    ...        ...                    ...
# 667  2016    32933.8         Cidade de Deus
# 668  2017    32610.6         Cidade de Deus
# 669  2018    32287.4         Cidade de Deus
# 670  2019    31964.2         Cidade de Deus
# 671  2020    31641.0         Cidade de Deus
#
# [672 rows x 3 columns]

# %%
from clean import get_bairros_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/7b/hgztdlzd4k76rwydg33k1vhm0000gn/T/ipykernel_54361/2578807512.py in <module>
# ----> 1 from clean import get_bairros_data
#
# ImportError: cannot import name 'get_bairros_data' from 'clean' (/Users/desireepetrilli/Documents/event-forecast-rio/clean.py)

# %%
rio_df
# Out:
#               Crime_ID         Crime_sub_type     Crime_type  \
# 0        00787401-2009  Lesão corporal dolosa  Não se aplica
# 1        01137431-2009  Lesão corporal dolosa  Não se aplica
# 2        02023941-2009  Lesão corporal dolosa  Não se aplica
# 4        04751871-2009  Lesão corporal dolosa  Não se aplica
# 5        04909311-2009                 Ameaça  Não se aplica
# ...                ...                    ...            ...
# 1220307  96730181-2019      Roubo em coletivo          Roubo
# 1220308  97578571-2019     Furto a transeunte          Furto
# 1220309  98313421-2019     Furto a transeunte          Furto
# 1220310  98452031-2019     Furto a transeunte          Furto
# 1220311  98535391-2019     Furto a transeunte          Furto
#
#                     Police_station            Place_type           Date_Time  \
# 0         043a. Pedra de Guaratiba                 Praia 2009-01-01 04:30:00
# 1               035a. Campo Grande            Residência 2009-01-01 19:00:00
# 2             040a. Honório Gurgel            Residência 2008-12-31 20:30:00
# 4               035a. Campo Grande           Via pública 2009-01-01 01:30:00
# 5                     039a. Pavuna            Residência 2009-01-01 03:03:00
# ...                            ...                   ...                 ...
# 1220307  027a. Vicente de Carvalho  Interior de coletivo 2019-12-19 20:55:00
# 1220308           012a. Copacabana                 Praia 2019-12-31 17:00:00
# 1220309           012a. Copacabana           Via pública 2019-12-29 19:00:00
# 1220310               014a. Leblon  Interior de coletivo 2019-12-30 11:45:00
# 1220311   004a. Praça da República   Estação metroviária 2019-12-31 19:00:00
#
#                    Neighborhood            RA
# 0            Pedra de Guaratiba     Guaratiba
# 1                    Santissimo  Campo Grande
# 2                Honorio Gurgel     Madureira
# 4                  Campo Grande  Campo Grande
# 5        Ricardo de Albuquerque      Anchieta
# ...                         ...           ...
# 1220307                   Iraja         Iraja
# 1220308              Copacabana    Copacabana
# 1220309              Copacabana    Copacabana
# 1220310                  Centro        Centro
# 1220311                  Centro        Centro
#
# [1189412 rows x 8 columns]

# %%
def get_format(data):
    data["Date"] = data["Date_Time"].dt.date
    preprocessed_data = data.groupby(["AR", "Date"]).count()[["Crime_ID"]]
    preprocessed_data.rename(columns={"Crime_ID":"nb_crimes"}, inplace=True)
    
    ## add a column with yearly population per AR
    pop_clean = clean_pop_data()
    preprocessed_data["year_temp"] = preprocessed_data.index.map(lambda x: x[1].year)
    input_merge = preprocessed_data.reset_index()
    data_merge = pd.merge(left=input_merge, right=pop_clean, left_on=["AR","year_temp"],\
        right_on=["administrative_regions", "Ano"])
    data_merge.drop(columns=["administrative_regions","Ano"], inplace = True)
    preprocessed_data.drop(columns=["year_temp"], inplace = True)
    ## compute nb crimes / 1000 inhabitants
    data_merge["nb_crimes_1000"]=data_merge.nb_crimes / data_merge.Populacao*1000
    data_merge.drop(columns=["nb_crimes","Populacao","year_temp"], inplace=True)
    data_merge.set_index(["AR","Date"],inplace=True)
    ##
    preprocessed_data = preprocessed_data.unstack(level=0)
    preprocessed_data = preprocessed_data.replace(np.nan, 0).astype(int)
    preprocessed_data_1000 = data_merge.unstack(level=0)
    preprocessed_data_1000 = preprocessed_data_1000.replace(np.nan, 0)
    return preprocessed_data, preprocessed_data_1000

# %%
preprocessed_data, preprocessed_data_1000 = get_format(rio_df)

# %%
preprocessed_data
# Out:
#            nb_crimes                                                     \
# AR          Anchieta Bangu Barra da Tijuca Botafogo Campo Grande Centro
# Date
# 2008-01-31         0     0               0        0            0      1
# 2008-02-01         0     0               0        0            0      0
# 2008-02-02         0     0               0        0            0      0
# 2008-02-03         0     0               0        0            0      0
# 2008-02-07         0     0               0        0            0      0
# ...              ...   ...             ...      ...          ...    ...
# 2019-12-28         7    16              11        9           13     16
# 2019-12-29         9     7               9       11            7      7
# 2019-12-30         5    14              12       10            8     10
# 2019-12-31         6     7               3        5            5      5
# 2020-01-01         0     0               0        1            0      0
#
#                                                                    ...        \
# AR         Cidade de Deus Complexo do Alemao Copacabana Guaratiba  ... Ramos
# Date                                                               ...
# 2008-01-31              0                  0          0         0  ...     1
# 2008-02-01              0                  0          0         0  ...     0
# 2008-02-02              0                  0          0         0  ...     0
# 2008-02-03              0                  0          0         0  ...     0
# 2008-02-07              0                  0          0         0  ...     0
# ...                   ...                ...        ...       ...  ...   ...
# 2019-12-28              0                  0         19         3  ...     5
# 2019-12-29              2                  1         29         1  ...     4
# 2019-12-30              1                  0         10         3  ...     3
# 2019-12-31              0                  0         25         2  ...     4
# 2020-01-01              0                  0          0         0  ...     0
#
#                                                                   \
# AR         Realengo Rio Comprido Rocinha Santa Cruz Santa Teresa
# Date
# 2008-01-31        1            0       0          0            0
# 2008-02-01        1            0       0          1            0
# 2008-02-02        0            0       0          0            0
# 2008-02-03        0            0       0          1            0
# 2008-02-07        0            0       0          0            0
# ...             ...          ...     ...        ...          ...
# 2019-12-28        9            2       0          2            2
# 2019-12-29        9            4       0          5            2
# 2019-12-30        4            0       1          5            1
# 2019-12-31        2            3       0          1            0
# 2020-01-01        0            0       0          0            0
#
#
# AR         Sao Cristovao Tijuca Vigario Geral Vila Isabel
# Date
# 2008-01-31             0      0             0           0
# 2008-02-01             0      0             0           0
# 2008-02-02             0      0             0           0
# 2008-02-03             0      0             0           0
# 2008-02-07             0      0             0           0
# ...                  ...    ...           ...         ...
# 2019-12-28             3      3             2           8
# 2019-12-29             3      3             4           4
# 2019-12-30             3      6             2           5
# 2019-12-31             1      3             2           1
# 2020-01-01             0      0             0           0
#
# [4266 rows x 33 columns]

# %%
data_merge = pd.merge(left=input_merge, right=pop_clean, left_on=["AR","year_temp"],\
        right_on=["administrative_regions", "Ano"])

# %%
data_merge
# Out:
#                  AR        Date  nb_crimes  year_temp   Ano  Populacao  \
# 0          Anchieta  2008-04-14          1       2008  2008   156728.8
# 1          Anchieta  2008-04-15          1       2008  2008   156728.8
# 2          Anchieta  2008-07-01          1       2008  2008   156728.8
# 3          Anchieta  2008-08-09          1       2008  2008   156728.8
# 4          Anchieta  2008-09-06          1       2008  2008   156728.8
# ...             ...         ...        ...        ...   ...        ...
# 105004  Vila Isabel  2019-12-27          7       2019  2019   138408.0
# 105005  Vila Isabel  2019-12-28          8       2019  2019   138408.0
# 105006  Vila Isabel  2019-12-29          4       2019  2019   138408.0
# 105007  Vila Isabel  2019-12-30          5       2019  2019   138408.0
# 105008  Vila Isabel  2019-12-31          1       2019  2019   138408.0
#
#        administrative_regions
# 0                    Anchieta
# 1                    Anchieta
# 2                    Anchieta
# 3                    Anchieta
# 4                    Anchieta
# ...                       ...
# 105004            Vila Isabel
# 105005            Vila Isabel
# 105006            Vila Isabel
# 105007            Vila Isabel
# 105008            Vila Isabel
#
# [105009 rows x 7 columns]

# %%
data_merge
# Out:
#                  AR        Date  nb_crimes  year_temp  Populacao
# 0          Anchieta  2008-04-14          1       2008   156728.8
# 1          Anchieta  2008-04-15          1       2008   156728.8
# 2          Anchieta  2008-07-01          1       2008   156728.8
# 3          Anchieta  2008-08-09          1       2008   156728.8
# 4          Anchieta  2008-09-06          1       2008   156728.8
# ...             ...         ...        ...        ...        ...
# 105004  Vila Isabel  2019-12-27          7       2019   138408.0
# 105005  Vila Isabel  2019-12-28          8       2019   138408.0
# 105006  Vila Isabel  2019-12-29          4       2019   138408.0
# 105007  Vila Isabel  2019-12-30          5       2019   138408.0
# 105008  Vila Isabel  2019-12-31          1       2019   138408.0
#
# [105009 rows x 5 columns]

# %%
data_merge["nb_crimes_1000"]=data_merge.nb_crimes / data_merge.Populacao
data_merge
# Out:
#                  AR        Date  nb_crimes  year_temp  Populacao  \
# 0          Anchieta  2008-04-14          1       2008   156728.8
# 1          Anchieta  2008-04-15          1       2008   156728.8
# 2          Anchieta  2008-07-01          1       2008   156728.8
# 3          Anchieta  2008-08-09          1       2008   156728.8
# 4          Anchieta  2008-09-06          1       2008   156728.8
# ...             ...         ...        ...        ...        ...
# 105004  Vila Isabel  2019-12-27          7       2019   138408.0
# 105005  Vila Isabel  2019-12-28          8       2019   138408.0
# 105006  Vila Isabel  2019-12-29          4       2019   138408.0
# 105007  Vila Isabel  2019-12-30          5       2019   138408.0
# 105008  Vila Isabel  2019-12-31          1       2019   138408.0
#
#         nb_crimes_1000
# 0             0.000006
# 1             0.000006
# 2             0.000006
# 3             0.000006
# 4             0.000006
# ...                ...
# 105004        0.000051
# 105005        0.000058
# 105006        0.000029
# 105007        0.000036
# 105008        0.000007
#
# [105009 rows x 6 columns]

# %%
data_merge.drop(columns=["nb_crimes","Populacao"], inplace=True)
data_merge.drop(columns=["administrative_regions","Ano"], inplace = True)

# %%
data_merge

# %%
def get_popfile():
    '''import population file'''
    return pd.read_csv("raw_data/population_Rio.csv", sep=",")

def clean_pop_data():
    data= get_popfile()
    data = data.drop(columns=["DensidadeBruta", "DensidadeLiquida", "TaxaGeometrica"])

    # Get rid of Roman numbers in front of name of administrative regions
    splitted_regions = data['RegiaoAdministrativa'].str.split().str[1:]
    cleaned_regions = splitted_regions.str.join(" ")
    data["administrative_regions"] = cleaned_regions
    data = data.drop(columns=["RegiaoAdministrativa"])

    # Dictionary of population data per region for 2000-2020 in 5-years steps
    regions_dict = {}
    for region in data["administrative_regions"].unique():
        regions_dict[region] = data[data["administrative_regions"]==region]

    # Dataframe with years for 2000-2020 in 1-year steps
    year_df = pd.DataFrame(pd.period_range(min(data.Ano), max(data.Ano), freq="Y"), columns=["Ano"])
    year_df = year_df[["Ano"]].astype("str").astype("int64")

    # Extend time series to annual time series and interpolate lineraly the missing population data
    middle_dict = {}
    for k, v in regions_dict.items():
        middle_dict[k] = year_df.merge(v, how="left", on="Ano")
        middle_dict[k]["administrative_regions"].fillna(value=k, inplace=True)
        middle_dict[k]["Populacao"].interpolate(method='linear', inplace=True)


    # Create a new dataframe with cleand and extended population data
    empty = pd.DataFrame(columns=["Ano", "Populacao", "administrative_regions"])
    df = pd.concat(middle_dict).reset_index().drop(columns=["level_0", "level_1"])

    return df

# %%
pop_clean = clean_pop_data()

# %%
def data_pop_merge(data,pop_clean):
    '''Add population column to the main dataframe, per year and per AR'''
    data['Year'] = pd.DatetimeIndex(data.Date).year
    data_merge = pd.merge(left=data, right=pop_clean, left_on=["AR","Year"],\
        right_on=["administrative_regions", "Ano"])
    data_merge.drop(columns=["administrative_regions","Ano","Year"], inplace = True)
    return data_merge

# %%
rio_df_2
# Out:
#               Crime_ID         Crime_sub_type     Crime_type  \
# 0        00787401-2009  Lesão corporal dolosa  Não se aplica
# 1        01137431-2009  Lesão corporal dolosa  Não se aplica
# 2        02023941-2009  Lesão corporal dolosa  Não se aplica
# 4        04751871-2009  Lesão corporal dolosa  Não se aplica
# 5        04909311-2009                 Ameaça  Não se aplica
# ...                ...                    ...            ...
# 1220307  96730181-2019      Roubo em coletivo          Roubo
# 1220308  97578571-2019     Furto a transeunte          Furto
# 1220309  98313421-2019     Furto a transeunte          Furto
# 1220310  98452031-2019     Furto a transeunte          Furto
# 1220311  98535391-2019     Furto a transeunte          Furto
#
#                     Police_station            Place_type           Date_Time  \
# 0         043a. Pedra de Guaratiba                 Praia 2009-01-01 04:30:00
# 1               035a. Campo Grande            Residência 2009-01-01 19:00:00
# 2             040a. Honório Gurgel            Residência 2008-12-31 20:30:00
# 4               035a. Campo Grande           Via pública 2009-01-01 01:30:00
# 5                     039a. Pavuna            Residência 2009-01-01 03:03:00
# ...                            ...                   ...                 ...
# 1220307  027a. Vicente de Carvalho  Interior de coletivo 2019-12-19 20:55:00
# 1220308           012a. Copacabana                 Praia 2019-12-31 17:00:00
# 1220309           012a. Copacabana           Via pública 2019-12-29 19:00:00
# 1220310               014a. Leblon  Interior de coletivo 2019-12-30 11:45:00
# 1220311   004a. Praça da República   Estação metroviária 2019-12-31 19:00:00
#
#                    Neighborhood            RA
# 0            Pedra de Guaratiba     Guaratiba
# 1                    Santissimo  Campo Grande
# 2                Honorio Gurgel     Madureira
# 4                  Campo Grande  Campo Grande
# 5        Ricardo de Albuquerque      Anchieta
# ...                         ...           ...
# 1220307                   Iraja         Iraja
# 1220308              Copacabana    Copacabana
# 1220309              Copacabana    Copacabana
# 1220310                  Centro        Centro
# 1220311                  Centro        Centro
#
# [1189412 rows x 8 columns]

# %%
data_pop_merge(rio_df,pop_clean)
# Out:
#               Crime_ID                      Crime_sub_type     Crime_type  \
# 0        00787401-2009               Lesão corporal dolosa  Não se aplica
# 1        07177211-2009  Lesão corporal culposa de trânsito  Não se aplica
# 2        21813091-2009                              Ameaça  Não se aplica
# 3        37974231-2009               Lesão corporal dolosa  Não se aplica
# 4        73801671-2009               Lesão corporal dolosa  Não se aplica
# ...                ...                                 ...            ...
# 1135254  70645371-2019                   Furto de veículos          Furto
# 1135255  42741691-2019                    Homicídio doloso  Não se aplica
# 1135256  18847651-2019                  Furto a transeunte          Furto
# 1135257  68517021-2019           Furto de telefone celular          Furto
# 1135258  64044451-2019           Furto de telefone celular          Furto
#
#                    Police_station                     Place_type  \
# 0        043a. Pedra de Guaratiba                          Praia
# 1           016a. Barra da Tijuca                    Via pública
# 2        043a. Pedra de Guaratiba                     Residência
# 3        043a. Pedra de Guaratiba                    Via pública
# 4        043a. Pedra de Guaratiba                     Residência
# ...                           ...                            ...
# 1135254          021a. Bonsucesso                    Via pública
# 1135255        025a. Engenho Novo  Hospital, clínica e similares
# 1135256        025a. Engenho Novo                         Favela
# 1135257          021a. Bonsucesso           Interior de coletivo
# 1135258              009a. Catete                    Via pública
#
#                   Date_Time        Neighborhood           AR        Date  \
# 0       2009-01-01 04:30:00  Pedra de Guaratiba    Guaratiba  2009-01-01
# 1       2009-01-01 19:10:00  Barra de Guaratiba    Guaratiba  2009-01-01
# 2       2009-01-01 05:30:00           Guaratiba    Guaratiba  2009-01-01
# 3       2009-01-01 19:30:00           Guaratiba    Guaratiba  2009-01-01
# 4       2009-01-01 03:40:00  Barra de Guaratiba    Guaratiba  2009-01-01
# ...                     ...                 ...          ...         ...
# 1135254 2019-07-08 05:00:00         Jacarezinho  Jacarezinho  2019-07-08
# 1135255 2019-09-01 02:49:00         Jacarezinho  Jacarezinho  2019-09-01
# 1135256 2019-11-25 01:25:00         Jacarezinho  Jacarezinho  2019-11-25
# 1135257 2019-12-18 14:20:00         Jacarezinho  Jacarezinho  2019-12-18
# 1135258 2020-01-01 00:30:00            Flamengo     Botafogo  2020-01-01
#
#          Populacao
# 0         131901.6
# 1         131901.6
# 2         131901.6
# 3         131901.6
# 4         131901.6
# ...            ...
# 1135254    24065.0
# 1135255    24065.0
# 1135256    24065.0
# 1135257    24065.0
# 1135258   178122.0
#
# [1135259 rows x 10 columns]
